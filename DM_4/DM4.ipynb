# %% [markdown]
# ## DM lesson4
# Dans ce dataset: https://raw.githubusercontent.com/fspot/INFMDI-721/master/lesson5/products.csv, chaque ligne correspond à un produit alimentaire mis en vente par un utilisateur.
#
# Objectif: cleaner le dataset.
#
# - On aimerait avoir une colonne de prix unifiés en euros. Problème: la currency n'est pas indiquée pour tous les produits: il va falloir essayer de "deviner" les currency manquantes, en se basant sur l'adresse IP de l'utilisateur.
# - La colonne "infos" liste des ingrédients présents dans le produit. On préfèrerait avoir une colonne de type bool par ingrédient, indiquant si le produit contient ou non cet ingrédient.
# Voic une liste d'APIs qui peut vous être utile : https://github.com/public-apis/public-apis (mais vous pouvez en utiliser d'autres si vous le voulez).

# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('products.csv',sep=';')

# %%
df.head()
# Out:
#        username       ip_address                       product   price  \
# 0      ldrover0  666.666.666.666            Clam - Cherrystone   712.8
# 1      kizakov1             nope  Soup - Campbells Bean Medley  379.26
# 2      abromet2   240.177.79.234       Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49      Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239              Radish - Pickled  949.79
#
#                              infos
# 0                May contain sugar
# 1         Contains peanut and fish
# 2    Ingredients: mustard and fish
# 3                  Contains gluten
# 4  May contain sugar, egg and fish

# %%
df.groupby('infos').count().head()
# Out:
#                            username  ip_address  product  price
# infos
# Contains                          1           1        1      1
# Contains fish                     2           2        2      2
# Contains gluten                   1           1        1      1
# Contains gluten and egg           1           1        1      1
# Contains gluten and sugar         4           4        4      4

# %%
# Clean price column
df['currency'] = df['price'].str.split(" ").str[1]
df['price'] = df['price'].str.split(" ").str[0]
pd.to_numeric(df['price'],errors='raise')
df.head()
# Out:
#        username       ip_address                       product   price  \
# 0      ldrover0  666.666.666.666            Clam - Cherrystone   712.8
# 1      kizakov1             nope  Soup - Campbells Bean Medley  379.26
# 2      abromet2   240.177.79.234       Island Oasis - Lemonade  305.96
# 3  kkarolowski3    26.191.237.49      Water - Mineral, Natural  350.15
# 4     mbuckney4    58.90.204.239              Radish - Pickled  949.79
#
#                              infos currency
# 0                May contain sugar      NaN
# 1         Contains peanut and fish      NaN
# 2    Ingredients: mustard and fish      NaN
# 3                  Contains gluten      NaN
# 4  May contain sugar, egg and fish      NaN

# %%
# Clean infos
df['infos'] = df['infos'].str.lower()
df['infos'] = df['infos'].str.replace('may','')
df['infos'] = df['infos'].str.replace('contains','')
df['infos'] = df['infos'].str.replace('contain','')
df['infos'] = df['infos'].str.replace('ingredients','')
df['infos'] = df['infos'].str.replace(':','')
df['infos'] = df['infos'].str.replace('and ','')
df['infos'] = df['infos'].str.replace(', ',' ')
df['infos'] = df['infos'].str.replace('  ',' ')
df2 = df.join(df.infos.str.get_dummies(' '))

# %%
#del df2['infos']
df2.head(20)
# Out:
#         username       ip_address                       product   price  \
# 0       ldrover0  666.666.666.666            Clam - Cherrystone   712.8
# 1       kizakov1             nope  Soup - Campbells Bean Medley  379.26
# 2       abromet2   240.177.79.234       Island Oasis - Lemonade  305.96
# 3   kkarolowski3    26.191.237.49      Water - Mineral, Natural  350.15
# 4      mbuckney4    58.90.204.239              Radish - Pickled  949.79
# 5    bsnozzwell5     226.52.32.70                  Oil - Sesame  354.33
# 6    afairholme6  127.197.204.119          Chicken - Tenderloin  484.83
# 7       avowdon7    189.169.17.54          Dc Hikiage Hira Huba  111.56
# 8      epridham8  187.129.113.105                    Dried Figs   88.05
# 9      tkendrew9    22.32.234.215           Pop - Club Soda Can  861.25
# 10     cjagielaa   75.254.207.163                Cinnamon Rolls  966.34
# 11      jdolbeyb    17.105.113.72               Wine - Ice Wine  679.57
# 12    chaylandsc   208.239.186.79      Chicken Thigh - Bone Out  725.88
# 13     mvidelerd     116.18.56.20           Trout Rainbow Whole  178.58
# 14      jmulvine    87.198.88.207          Bread Crumbs - Panko  150.89
# 15  kcaldeyrouxf    138.44.156.99             Vector Energy Bar   72.51
# 16        ctaftg    18.61.195.234          Versatainer Nc - 888  373.96
# 17     ksumptonh   150.214.20.140    Bagel - Ched Chs Presliced   957.7
# 18       aloweri  157.197.190.113                       Dry Ice  963.32
# 19      sgarmeyj    219.75.213.15  Nantucket - Kiwi Berry Cktl.   772.7
#
#                           infos currency  egg  fish  gluten  milk  mustard  \
# 0                         sugar      NaN    0     0       0     0        0
# 1                   peanut fish      NaN    0     1       0     0        0
# 2                  mustard fish      NaN    0     1       0     0        1
# 3                        gluten      NaN    0     0       1     0        0
# 4                sugar egg fish      NaN    1     1       0     0        0
# 5                    sugar milk      MGA    0     0       0     1        0
# 6                         sugar      NaN    0     0       0     0        0
# 7                         sugar      NaN    0     0       0     0        0
# 8               sugar milk fish      NaN    0     1       0     1        0
# 9        peanut sugar milk fish      NaN    0     1       0     1        0
# 10        peanut sugar egg fish      NaN    1     1       0     0        0
# 11           mustard sugar milk      NaN    0     0       0     1        1
# 12                 gluten sugar      NaN    0     0       1     0        0
# 13                       peanut      NaN    0     0       0     0        0
# 14       gluten soja sugar milk      NaN    0     0       1     1        0
# 15       gluten soja sugar milk      NaN    0     0       1     1        0
# 16                   soja sugar      NaN    0     0       0     0        0
# 17             peanut sugar egg      EUR    1     0       0     0        0
# 18                   sugar milk      NaN    0     0       0     1        0
# 19   gluten soja sugar egg fish      NaN    1     1       1     0        0
#
#     peanut  soja  sugar
# 0        0     0      1
# 1        1     0      0
# 2        0     0      0
# 3        0     0      0
# 4        0     0      1
# 5        0     0      1
# 6        0     0      1
# 7        0     0      1
# 8        0     0      1
# 9        1     0      1
# 10       1     0      1
# 11       0     0      1
# 12       0     0      1
# 13       1     0      0
# 14       0     1      1
# 15       0     1      1
# 16       0     1      1
# 17       1     0      1
# 18       0     0      1
# 19       0     1      1

# %%
def checkCountry (IP):
    if requests.get('https://extreme-ip-lookup.com/json/'+ IP).json()['status'] == 'fail':
        return None
    else:
        return requests.get('https://extreme-ip-lookup.com/json/' + IP).json()['countryCode']

# %%
df2['country'] = df2.ip_address.apply(checkCountry)

# %%
def getCurrency(country):
    if country == None:
        return None
    if country == '':
        return None
    else:
        return requests.get('https://restcountries.eu/rest/v2/alpha/'+country).json()['currencies'][0]['code']

# %%
df2.currency = df2.country.apply(getCurrency)

# %%
def getExchangeRate(devise):
    if devise == None:
        return 1 
    if 'rates' not in requests.get('https://api.ratesapi.io/api/latest?base=USD;symbols='+devise).json():
        return 1
    else:
        return float(requests.get('https://api.ratesapi.io/api/latest?base=USD;symbols='+devise).json()['rates'][devise])

# %%
df2['price in $'] = round(df2.price.astype(float) / df2.currency.apply(getExchangeRate).astype(float),2)

# %%
df2.sort_values('price in $',ascending=False).head(20)
# Out:
#           username       ip_address                      product   price  \
# 48       tnusche1c   109.144.241.78             Tomatoes - Grape  852.58
# 17       ksumptonh   150.214.20.140   Bagel - Ched Chs Presliced   957.7
# 114       aatack36   158.197.55.255               Tamarind Paste  946.48
# 64     hreidshaw1s   104.137.59.250      Rice Pilaf, Dry,package  992.68
# 106     nlampkin2y    49.215.30.109     Tomato - Plum With Basil  990.81
# 49       ychuter1d   136.251.73.188  Coconut - Shredded, Unsweet  985.06
# 69     psemechik1x    38.360.77.106         Curry Paste - Madras  976.51
# 10       cjagielaa   75.254.207.163               Cinnamon Rolls  966.34
# 118    zembleton3a   134.10.200.254     Wine - Pinot Noir Latour  944.51
# 120     cgorusso3c   16.157.249.370  Pasta - Shells, Medium, Dry  940.51
# 174     bhackney4u   165.230.147.86             Chips - Assorted  938.69
# 185     gwalling55  155.124.149.117       Mushroom - Morels, Dry  937.43
# 141  bstollmeyer3x    100.31.73.144              Cheese - Asiago  932.02
# 164    hberinger4k     242.11.31.81          Extract - Raspberry   929.8
# 59        cwrenn1n   38.125.216.233      Cheese - Perron Cheddar  925.05
# 73       ptzuker21   86.115.203.240  Jam - Strawberry, 20 Ml Jar   828.1
# 176       dwynne4w   127.87.213.209      Lettuce Romaine Chopped  920.64
# 24           dpico    17.226.242.68     Bread - Pain Au Liat X12  917.69
# 188     rcreigan58   102.105.44.112   Juice - Grapefruit, 341 Ml  886.74
# 161        bbeel4h   178.90.118.137        Coffee - Beans, Whole   883.1
#
#                           infos currency  egg  fish  gluten  milk  mustard  \
# 48            peanut sugar fish      GBP    0     1       0     0        0
# 17             peanut sugar egg      EUR    1     0       0     0        0
# 114           gluten sugar fish      EUR    0     1       1     0        0
# 64               soja sugar egg      USD    1     0       0     0        0
# 106    peanut mustard sugar egg      TWD    1     0       0     0        1
# 49    peanut mustard sugar milk      USD    0     0       0     1        1
# 69      mustard sugar milk fish     None    0     1       0     1        1
# 10        peanut sugar egg fish      USD    1     1       0     0        0
# 118             soja sugar milk      USD    0     0       0     1        0
# 120                gluten sugar     None    0     0       1     0        0
# 174           peanut soja sugar      USD    0     0       0     0        0
# 185            peanut soja fish      USD    0     1       0     0        0
# 141       peanut soja sugar egg      USD    1     0       0     0        0
# 164      gluten sugar milk fish     None    0     1       1     1        0
# 59             gluten soja milk      USD    0     0       1     1        0
# 73               sugar egg fish      EUR    1     1       0     0        0
# 176       gluten soja sugar egg     None    1     0       1     0        0
# 24              sugar milk fish      USD    0     1       0     1        0
# 188            gluten sugar egg      TND    1     0       1     0        0
# 161                peanut sugar      KZT    0     0       0     0        0
#
#      peanut  soja  sugar country  price in $
# 48        1     0      1      GB     1099.23
# 17        1     0      1      ES     1067.26
# 114       0     0      1      SK     1054.76
# 64        0     1      1      US      992.68
# 106       1     0      1      TW      990.81
# 49        1     0      1      US      985.06
# 69        0     0      1    None      976.51
# 10        1     0      1      US      966.34
# 118       0     1      1      US      944.51
# 120       0     0      1    None      940.51
# 174       1     1      1      US      938.69
# 185       1     1      0      US      937.43
# 141       1     1      1      US      932.02
# 164       0     0      1              929.80
# 59        0     1      0      US      925.05
# 73        0     0      1      FI      922.83
# 176       0     1      1              920.64
# 24        0     0      1      US      917.69
# 188       0     0      1      TN      886.74
# 161       1     0      1      KZ      883.10
